# %% [markdown]
# ## Week 2 Day 2
#
# Our first Agentic Framework project!!
#
# Prepare yourself for something ridiculously easy.
#
# We're going to build a simple Agent system for generating cold sales outreach emails:
# 1. Agent workflow
# 2. Use of tools to call functions
# 3. Agent collaboration via Tools and Handoffs

# %% [markdown]
# ## Before we start - some setup:
#
#
# Please visit Sendgrid at: https://sendgrid.com/
#
# (Sendgrid is a Twilio company for sending emails.)
#
# If SendGrid gives you problems, see the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# Please set up an account - it's free! (at least, for me, right now).
#
# Once you've created an account, click on:
#
# Settings (left sidebar) >> API Keys >> Create API Key (button on top right)
#
# Copy the key to the clipboard, then add a new line to your .env file:
#
# `SENDGRID_API_KEY=xxxx`
#
# And also, within SendGrid, go to:
#
# Settings (left sidebar) >> Sender Authentication >> "Verify a Single Sender"
# and verify that your own email address is a real email address, so that SendGrid can send emails for you.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
import asyncio

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from agents.tracing import set_tracing_export_api_key

tracing_api_key = os.environ["OPENAI_API_KEY"]
set_tracing_export_api_key(tracing_api_key)

# %%
# Let's just check emails are working for you

def send_test_email():
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("filomenaforina@gmail.com")  # Change to your verified sender
    to_email = To("filomenaforina@outlook.com")  # Change to your recipient
    content = Content("text/plain", "This is an important test email")
    mail = Mail(from_email, to_email, "Test email", content).get()
    response = sg.client.mail.send.post(request_body=mail)
    print(response.status_code)

send_test_email()
# Out:
# 202

# %% [markdown]
# ### Did you receive the test email
#
# If you get a 202, then you're good to go!
#
# #### Certificate error
#
# If you get an error SSL: CERTIFICATE_VERIFY_FAILED then students Chris S and Oleksandr K have suggestions:
# First run this: `!uv pip install --upgrade certifi`
# Next, run this:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# #### Other errors or no email
#
# If there are other problems, you'll need to check your API key and your verified sender email address in the SendGrid dashboard
#
# Or use the alternative implementation using "Resend Email" in community_contributions/2_lab2_with_resend_email
#
# (Or - you could always replace the email sending code below with a Pushover call, or something to simply write to a flat file)

# %% [markdown]
# ## Step 1: Agent workflow

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="litellm/gemini/gemini-2.5-flash-preview-05-20"
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="litellm/gemini/gemini-2.5-flash-preview-05-20"
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="litellm/gemini/gemini-2.5-flash-preview-05-20"
)

# %%
result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")

# This code generates a cold sales email and the output is written as soon as it is available
async for event in result.stream_events():
    if event.type == "raw_response_event":
        # Only print if event.data is a ResponseTextDeltaEvent and has delta attribute
        if isinstance(event.data, ResponseTextDeltaEvent):
            print(event.data.delta, end="", flush=True)
        elif hasattr(event.data, "delta"):
            print(event.data.delta, end="", flush=True)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[10], line 4
#       1 result = Runner.run_streamed(sales_agent1, input="Write a cold sales email")
#       3 # This code generates a cold sales email and the output is written as soon as it is available
# ----> 4 async for event in result.stream_events():
#       5     if event.type == "raw_response_event":
#       6         # Only print if event.data is a ResponseTextDeltaEvent and has delta attribute
#       7         if isinstance(event.data, ResponseTextDeltaEvent):
#
# File c:\Users\filom\OneDrive\Documents\Agents\.venv\Lib\site-packages\agents\result.py:215, in RunResultStreaming.stream_events(self)
#     212 self._cleanup_tasks()
#     214 if self._stored_exception:
# --> 215     raise self._stored_exception
#
# File c:\Users\filom\OneDrive\Documents\Agents\.venv\Lib\site-packages\agents\run.py:685, in AgentRunner._start_streaming(cls, starting_input, streamed_result, starting_agent, max_turns, hooks, context_wrapper, run_config, previous_response_id)
#     674     streamed_result._input_guardrails_task = asyncio.create_task(
#     675         cls._run_input_guardrails_with_queue(
#     676             starting_agent,
#    (...)    682         )
#     683     )
#     684 try:
# --> 685     turn_result = await cls._run_single_turn_streamed(
#     686         streamed_result,
#     687         current_agent,
#     688         hooks,
#     689         context_wrapper,
#     690         run_config,
#     691         should_run_agent_start_hooks,
#     692         tool_use_tracker,
#     693         all_tools,
#     694         previous_response_id,
#     695     )
#     696     should_run_agent_start_hooks = False
#     698     streamed_result.raw_responses = streamed_result.raw_responses + [
#     699         turn_result.model_response
#     700     ]
#
# File c:\Users\filom\OneDrive\Documents\Agents\.venv\Lib\site-packages\agents\run.py:812, in AgentRunner._run_single_turn_streamed(cls, streamed_result, agent, hooks, context_wrapper, run_config, should_run_agent_start_hooks, tool_use_tracker, all_tools, previous_response_id)
#     809 input.extend([item.to_input_item() for item in streamed_result.new_items])
#     811 # 1. Stream the output events
# --> 812 async for event in model.stream_response(
#     813     system_prompt,
#     814     input,
#     815     model_settings,
#     816     all_tools,
#     817     output_schema,
#     818     handoffs,
#     819     get_model_tracing_impl(
#     820         run_config.tracing_disabled, run_config.trace_include_sensitive_data
#     821     ),
#     822     previous_response_id=previous_response_id,
#     823     prompt=prompt_config,
#     824 ):
#     825     if isinstance(event, ResponseCompletedEvent):
#     826         usage = (
#     827             Usage(
#     828                 requests=1,
#    (...)    836             else Usage()
#     837         )
#
# File c:\Users\filom\OneDrive\Documents\Agents\.venv\Lib\site-packages\agents\extensions\models\litellm_model.py:181, in LitellmModel.stream_response(self, system_instructions, input, model_settings, tools, output_schema, handoffs, tracing, previous_response_id, prompt)
#     167 response, stream = await self._fetch_response(
#     168     system_instructions,
#     169     input,
#    (...)    177     prompt=prompt,
#     178 )
#     180 final_response: Response | None = None
# --> 181 async for chunk in ChatCmplStreamHandler.handle_stream(response, stream):
#     182     yield chunk
#     184     if chunk.type == "response.completed":
#
# File c:\Users\filom\OneDrive\Documents\Agents\.venv\Lib\site-packages\agents\models\chatcmpl_stream_handler.py:118, in ChatCmplStreamHandler.handle_stream(cls, response, stream)
#     105     yield ResponseContentPartAddedEvent(
#     106         content_index=state.text_content_index_and_output[0],
#     107         item_id=FAKE_RESPONSES_ID,
#    (...)    115         sequence_number=sequence_number.get_and_increment(),
#     116     )
#     117 # Emit the delta for this segment of content
# --> 118 yield ResponseTextDeltaEvent(
#     119     content_index=state.text_content_index_and_output[0],
#     120     delta=delta.content,
#     121     item_id=FAKE_RESPONSES_ID,
#     122     output_index=0,
#     123     type="response.output_text.delta",
#     124     sequence_number=sequence_number.get_and_increment(),
#     125 )
#     126 # Accumulate the text into the response part
#     127 state.text_content_index_and_output[1].text += delta.content
#
# File c:\Users\filom\OneDrive\Documents\Agents\.venv\Lib\site-packages\pydantic\main.py:253, in BaseModel.__init__(self, **data)
#     251 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     252 __tracebackhide__ = True
# --> 253 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     254 if self is not validated_self:
#     255     warnings.warn(
#     256         'A custom validator is returning a value other than `self`.\n'
#     257         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     258         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     259         stacklevel=2,
#     260     )
#
# ValidationError: 1 validation error for ResponseTextDeltaEvent
# logprobs
#   Field required [type=missing, input_value={'content_index': 0, 'del...', 'sequence_number': 3}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/missing

# %%
message = "Write a cold sales email"

with trace("Parallel cold emails"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )

outputs = [result.final_output for result in results]

for output in outputs:
    print(output + "\n\n")
# Out:
# Subject: Optimizing Your SOC2 Compliance & Audit Readiness
#
# Dear [Prospect Name],
#
# I'm reaching out because organizations like yours often face significant challenges navigating the complexities of SOC2 compliance and preparing for audits. The journey to achieving and maintaining SOC2 Type 2 certification can be a resource-intensive, time-consuming, and often daunting task, diverting valuable internal talent from core strategic initiatives.
#
# At ComplAI, we've developed an AI-powered SaaS solution specifically designed to revolutionize this process. Our platform transforms the traditional, manual approach to SOC2 into an efficient, automated, and continuous journey.
#
# With ComplAI, you can expect:
#
# *   **Accelerated Compliance:** Leverage AI to quickly identify gaps, automate evidence collection, and streamline policy management, significantly reducing the time to achieve readiness.
# *   **Continuous Readiness:** Maintain real-time visibility into your compliance posture, ensuring you're not just ready for an audit, but continuously aligned with SOC2 requirements.
# *   **Seamless Audit Experience:** Generate comprehensive, auditor-ready reports and documentation with ease, transforming a typically stressful event into a smooth, predictable process.
# *   **Resource Optimization:** Free up your valuable team members from repetitive compliance tasks, allowing them to focus on innovation and growth.
#
# Would you be open to a brief, 15-minute conversation next week to explore how ComplAI could specifically benefit [Prospect's Company Name] in simplifying your SOC2 compliance journey? Please let me know what time works best for you, or if another colleague would be a more appropriate contact.
#
# Thank you for your time and consideration.
#
# Best regards,
#
# [Your Name]
# [Your Title]
# ComplAI
# [Your Website]
#
#
# Subject: SOC2: Less 'Oh No!' More 'Oh Yeah!' (and AI helped write this!)
#
# Hi [Prospect Name],
#
# Let's be honest, receiving a cold email about SOC2 compliance probably ranks somewhere between "unexpected Monday meeting" and "finding a single grey hair." Not exactly thrilling.
#
# You're busy building something awesome, innovating, and generally making the world a better, more efficient place. The last thing you need is to spend countless hours wrestling with spreadsheets, policies, and the general bureaucratic beast that is audit preparation. It's like trying to assemble IKEA furniture blindfolded, using only a spoon and the vague memory of a dream.
#
# That's where ComplAI waltzes in, probably wearing a tiny digital tuxedo.
#
# We've built an **AI-powered SaaS tool** that transforms SOC2 compliance from a soul-crushing chore into... well, not exactly a vacation, but definitely a well-oiled, efficient process. Think of us as your personal compliance concierge, powered by algorithms that love documentation more than any human ever could (bless their digital hearts).
#
# **ComplAI helps you:**
# *   Automate evidence collection (poof! gone are those manual hunts).
# *   Structure your policies (so auditors don't think you made them up on the fly).
# *   Prepare for audits with confidence (less "oh no," more "we got this!").
#
# In short, we give you back your precious time and sanity, so you can focus on, you know, your actual job. No more late nights frantically searching for a screenshot from six months ago.
#
# Would you be open to a super quick, no-pressure 15-minute chat sometime this week? We can explore if ComplAI could be your secret weapon against compliance chaos. Even if it's just to confirm you *don't* need a robot butler for your SOC2 (yet!), it'd be great to connect.
#
# Cheers to fewer compliance-induced stress dreams,
#
# [Your Name]
# Humor & Compliance Evangelist (a.k.a. Sales)
# ComplAI – Because Your Brain Has Better Things To Do
# [Your Website]
# [Your LinkedIn Profile (Optional)]
#
# P.S. If you've ever secretly wished for an AI to handle your admin, we're basically that, but for SOC2. And without the risk of Skynet taking over your audit. (Probably.)
#
#
# Subject: Streamline SOC2 Compliance with AI
#
# Hi [Name],
#
# Navigating SOC2 compliance and audits is complex. ComplAI offers an AI-powered SaaS tool that simplifies the entire process, getting you audit-ready faster and with less manual effort.
#
# We help companies like yours automate the heavy lifting, saving significant time and resources.
#
# Would you be open to a brief 15-minute call next week to see how ComplAI can streamline your next audit?
#
# Best,
#
# [Your Name]
# Sales Agent, ComplAI
# [Your Website] | [Your LinkedIn (Optional)]

# %%
sales_picker = Agent(
    name="sales_picker",
    instructions="You pick the best cold sales email from the given options. \
Imagine you are a customer and pick the one you are most likely to respond to. \
Do not give an explanation; reply with the selected email only.",
    model="litellm/gemini/gemini-2.5-flash-preview-05-20"
)

# %%
message = "Write a cold sales email"

with trace("Selection from sales people"):
    results = await asyncio.gather(
        Runner.run(sales_agent1, message),
        Runner.run(sales_agent2, message),
        Runner.run(sales_agent3, message),
    )
    outputs = [result.final_output for result in results]

    emails = "Cold sales emails:\n\n" + "\n\nEmail:\n\n".join(outputs)

    best = await Runner.run(sales_picker, emails)

    print(f"Best sales email:\n{best.final_output}")
# Out:
# Best sales email:
# Subject: Quick Q: Is SOC2 compliance your favorite hobby? (Probably not.)
#
# Hi [Prospect Name],
#
# Let's be real. No one wakes up on a Monday morning thinking, "Yay! Today I get to dive deep into my SOC2 readiness!"
#
# It's usually more like, "Where *is* that policy document? Did we update *that* control? And who keeps moving the finish line on these things?!" The endless documentation, the policy updates, the feeling you're trying to nail jelly to a wall while blindfolded... it's enough to make even the most zen founder consider a career as a professional competitive napper.
#
# That's where ComplAI waltzes in, cape optional (but highly recommended for dramatic effect).
#
# We're like having a team of brilliant, tirelessly efficient compliance experts, all powered by mind-bending AI, working 24/7. Think of us as your personal SOC2 Sherpa, guiding you up that mountain of requirements, no oxygen mask or questionable spreadsheets required.
#
# ComplAI doesn't just *help* with SOC2; we make it almost, dare I say, *enjoyable* (okay, significantly less painful). We streamline everything from gap analysis to audit readiness, saving you precious hours, headaches, and probably a few gray hairs. So you can focus on building your amazing product, not battling bureaucracy.
#
# Fancy a quick 15-minute chat to see how ComplAI can turn your compliance frown upside down? No hard sell, just a genuinely helpful conversation (and maybe a terrible pun or two from my end).
#
# Let me know if a quick call sometime next week works. If you're truly happy spending your weekends deciphering control matrices, I applaud your dedication, but also... why? 😉
#
# Cheers,
#
# [My Name]
# Your Friendly Neighborhood Compliance Whisperer at ComplAI
# (We make SOC2 audits less "oh no" and more "let's go!")
# [Link to ComplAI Website]
# [My LinkedIn Profile (Optional)]

# %% [markdown]
# Now go and check out the trace:
#
# https://platform.openai.com/traces

# %% [markdown]
# ## Part 2: use of tools
#
# Now we will add a tool to the mix.
#
# Remember all that json boilerplate and the `handle_tool_calls()` function with the if logic..

# %%
sales_agent1 = Agent(
        name="Professional Sales Agent",
        instructions=instructions1,
        model="litellm/gemini/gemini-2.5-flash-preview-05-20",
)

sales_agent2 = Agent(
        name="Engaging Sales Agent",
        instructions=instructions2,
        model="litellm/gemini/gemini-2.5-flash-preview-05-20",
)

sales_agent3 = Agent(
        name="Busy Sales Agent",
        instructions=instructions3,
        model="litellm/gemini/gemini-2.5-flash-preview-05-20",
)

# %%
sales_agent1
# Out:
# Agent(name='Professional Sales Agent', instructions='You are a sales agent working for ComplAI, a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. You write professional, serious cold emails.', prompt=None, handoff_description=None, handoffs=[], model='litellm/gemini/gemini-2.5-flash-preview-05-20', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %% [markdown]
# ## Steps 2 and 3: Tools and Agent interactions
#
# Remember all that boilerplate json?
#
# Simply wrap your function with the decorator `@function_tool`

# %%
@function_tool
def send_email(body: str):
    """ Send out an email with the given body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("filomenaforina@gmail.com")  # Change to your verified sender
    to_email = To("filomenaforina@outlook.com")  # Change to your recipient
    content = Content("text/plain", body)
    mail = Mail(from_email, to_email, "Sales email", content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %% [markdown]
# ### This has automatically been converted into a tool, with the boilerplate json created

# %%
# Let's look at it
send_email
# Out:
# FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A836D5A2A0>, strict_json_schema=True, is_enabled=True)

# %% [markdown]
# ### And you can also convert an Agent into a tool

# %%
tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description="Write a cold sales email")
tool1
# Out:
# FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EEE80>, strict_json_schema=True, is_enabled=True)

# %% [markdown]
# ### So now we can gather all the tools together:
#
# A tool for each of our 3 email-writing agents
#
# And a tool for our function to send emails

# %%
description = "Write a cold sales email"

tool1 = sales_agent1.as_tool(tool_name="sales_agent1", tool_description=description)
tool2 = sales_agent2.as_tool(tool_name="sales_agent2", tool_description=description)
tool3 = sales_agent3.as_tool(tool_name="sales_agent3", tool_description=description)

tools = [tool1, tool2, tool3, send_email]

tools
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EF880>, strict_json_schema=True, is_enabled=True),
#  FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4ECF40>, strict_json_schema=True, is_enabled=True),
#  FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EE660>, strict_json_schema=True, is_enabled=True),
#  FunctionTool(name='send_email', description='Send out an email with the given body to all sales prospects', params_json_schema={'properties': {'body': {'title': 'Body', 'type': 'string'}}, 'required': ['body'], 'title': 'send_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A836D5A2A0>, strict_json_schema=True, is_enabled=True)]

# %% [markdown]
# ## And now it's time for our Sales Manager - our planning agent

# %%
# Improved instructions thanks to student Guillermo F.

instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
 
3. Use the send_email tool to send the best email (and only the best email) to the user.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must send ONE email using the send_email tool — never more than one.
"""


sales_manager = Agent(name="Sales Manager", instructions=instructions, tools=tools, model="gpt-4o-mini")

message = "Send a cold sales email addressed to 'Dear CEO'"

with trace("Sales manager"):
    result = await Runner.run(sales_manager, message)

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Wait - you didn't get an email??</h2>
#             <span style="color:#ff7800;">With much thanks to student Chris S. for describing his issue and fixes.
#             If you don't receive an email after running the prior cell, here are some things to check: <br/>
#             First, check your Spam folder! Several students have missed that the emails arrived in Spam!<br/>Second, print(result) and see if you are receiving errors about SSL.
#             If you're receiving SSL errors, then please check out theses <a href="https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d">networking tips</a> and see the note in the next cell. Also look at the trace in OpenAI, and investigate on the SendGrid website, to hunt for clues. Let me know if I can help!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And one more suggestion to send emails from student Oleksandr on Windows 11:
#
# If you are getting certificate SSL errors, then:
# Run this in a terminal: `uv pip install --upgrade certifi`
#
# Then run this code:
# ```python
# import certifi
# import os
# os.environ['SSL_CERT_FILE'] = certifi.where()
# ```
#
# Thank you Oleksandr!

# %% [markdown]
# ## Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# ### Handoffs represent a way an agent can delegate to an agent, passing control to it
#
# Handoffs and Agents-as-tools are similar:
#
# In both cases, an Agent can collaborate with another Agent
#
# With tools, control passes back
#
# With handoffs, control passes across

# %%
subject_instructions = "You can write a subject for a cold sales email. \
You are given a message and you need to write a subject for an email that is likely to get a response."

html_instructions = "You can convert a text email body to an HTML email body. \
You are given a text email body which might have some markdown \
and you need to convert it to an HTML email body with simple, clear, compelling layout and design."

subject_writer = Agent(name="Email subject writer", instructions=subject_instructions, model="gpt-4o-mini")
subject_tool = subject_writer.as_tool(tool_name="subject_writer", tool_description="Write a subject for a cold sales email")

html_converter = Agent(name="HTML email body converter", instructions=html_instructions, model="gpt-4o-mini")
html_tool = html_converter.as_tool(tool_name="html_converter",tool_description="Convert a text email body to an HTML email body")

# %%
@function_tool
def send_html_email(subject: str, html_body: str) -> Dict[str, str]:
    """ Send out an email with the given subject and HTML body to all sales prospects """
    sg = sendgrid.SendGridAPIClient(api_key=os.environ.get('SENDGRID_API_KEY'))
    from_email = Email("filomenaforina@gmail.com")  # Change to your verified sender
    to_email = To("filomenaforina@outlook.com")  # Change to your recipient
    content = Content("text/html", html_body)
    mail = Mail(from_email, to_email, subject, content).get()
    sg.client.mail.send.post(request_body=mail)
    return {"status": "success"}

# %%
tools = [subject_tool, html_tool, send_html_email]

# %%
tools
# Out:
# [FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'subject_writer_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EED40>, strict_json_schema=True, is_enabled=True),
#  FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'html_converter_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EE5C0>, strict_json_schema=True, is_enabled=True),
#  FunctionTool(name='send_html_email', description='Send out an email with the given subject and HTML body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EC900>, strict_json_schema=True, is_enabled=True)]

# %%
instructions ="You are an email formatter and sender. You receive the body of an email to be sent. \
You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. \
Finally, you use the send_html_email tool to send the email with the subject and HTML body."


emailer_agent = Agent(
    name="Email Manager",
    instructions=instructions,
    tools=tools,
    model="litellm/gemini/gemini-2.5-flash-preview-05-20",
    handoff_description="Convert an email to HTML and send it")

# %% [markdown]
# ### Now we have 3 tools and 1 handoff

# %%
tools = [tool1, tool2, tool3]
handoffs = [emailer_agent]
print(tools)
print(handoffs)
# Out:
# [FunctionTool(name='sales_agent1', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent1_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EF880>, strict_json_schema=True, is_enabled=True), FunctionTool(name='sales_agent2', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent2_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4ECF40>, strict_json_schema=True, is_enabled=True), FunctionTool(name='sales_agent3', description='Write a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'sales_agent3_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EE660>, strict_json_schema=True, is_enabled=True)]
# [Agent(name='Email Manager', instructions='You are an email formatter and sender. You receive the body of an email to be sent. You first use the subject_writer tool to write a subject for the email, then use the html_converter tool to convert the body to HTML. Finally, you use the send_html_email tool to send the email with the subject and HTML body.', prompt=None, handoff_description='Convert an email to HTML and send it', handoffs=[], model='litellm/gemini/gemini-2.5-flash-preview-05-20', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, metadata=None, store=None, include_usage=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), tools=[FunctionTool(name='subject_writer', description='Write a subject for a cold sales email', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'subject_writer_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EED40>, strict_json_schema=True, is_enabled=True), FunctionTool(name='html_converter', description='Convert a text email body to an HTML email body', params_json_schema={'properties': {'input': {'title': 'Input', 'type': 'string'}}, 'required': ['input'], 'title': 'html_converter_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EE5C0>, strict_json_schema=True, is_enabled=True), FunctionTool(name='send_html_email', description='Send out an email with the given subject and HTML body to all sales prospects', params_json_schema={'properties': {'subject': {'title': 'Subject', 'type': 'string'}, 'html_body': {'title': 'Html Body', 'type': 'string'}}, 'required': ['subject', 'html_body'], 'title': 'send_html_email_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x000001A83D4EC900>, strict_json_schema=True, is_enabled=True)], mcp_servers=[], mcp_config={}, input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)]

# %%
# Improved instructions thanks to student Guillermo F.

sales_manager_instructions = """
You are a Sales Manager at ComplAI. Your goal is to find the single best cold sales email using the sales_agent tools.
 
Follow these steps carefully:
1. Generate Drafts: Use all three sales_agent tools to generate three different email drafts. Do not proceed until all three drafts are ready.
 
2. Evaluate and Select: Review the drafts and choose the single best email using your judgment of which one is most effective.
You can use the tools multiple times if you're not satisfied with the results from the first try.
 
3. Handoff for Sending: Pass ONLY the winning email draft to the 'Email Manager' agent. The Email Manager will take care of formatting and sending.
 
Crucial Rules:
- You must use the sales agent tools to generate the drafts — do not write them yourself.
- You must hand off exactly ONE email to the Email Manager — never more than one.
"""


sales_manager = Agent(
    name="Sales Manager",
    instructions=sales_manager_instructions,
    tools=tools,
    handoffs=handoffs,
    model="litellm/gemini/gemini-2.5-flash-preview-05-20")

message = "Send out a cold sales email addressed to Dear CEO from Alice"

with trace("Automated SDR"):
    result = await Runner.run(sales_manager, message)
# Out:
# Error getting response: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}. (request_id: req_75eaf76ea15dd9138e2f4f880fe0af4b)

# %% [markdown]
# ### Remember to check the trace
#
# https://platform.openai.com/traces
#
# And then check your email!!

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Can you identify the Agentic design patterns that were used here?<br/>
#             What is the 1 line that changed this from being an Agentic "workflow" to "agent" under Anthropic's definition?<br/>
#             Try adding in more tools and Agents! You could have tools that handle the mail merge to send to a list.<br/><br/>
#             HARD CHALLENGE: research how you can have SendGrid call a Callback webhook when a user replies to an email,
#             Then have the SDR respond to keep the conversation going! This may require some "vibe coding" 😂
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">This is immediately applicable to Sales Automation; but more generally this could be applied to  end-to-end automation of any business process through conversations and tools. Think of ways you could apply an Agent solution
#             like this in your day job.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Extra note:
#
# Google has released their Agent Development Kit (ADK). It's not yet got the traction of the other frameworks on this course, but it's getting some attention. It's interesting to note that it looks quite similar to OpenAI Agents SDK. To give you a preview, here's a peak at sample code from ADK:
#
# ```
# root_agent = Agent(
#     name="weather_time_agent",
#     model="gemini-2.0-flash",
#     description="Agent to answer questions about the time and weather in a city.",
#     instruction="You are a helpful agent who can answer user questions about the time and weather in a city.",
#     tools=[get_weather, get_current_time]
# )
# ```
#
# Well, that looks familiar!
#
# And a student has contributed a customer care agent in community_contributions that uses ADK.
